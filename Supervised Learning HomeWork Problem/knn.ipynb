# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
iris = sns.load_dataset("iris")
iris["species"] = iris["species"].map({"setosa": 0, "versicolor": 1, "virginica": 2})
X = iris.drop(columns=["species"])
y = iris["species"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
pipe = Pipeline([("scaler", StandardScaler()), ("knn", NearestNeighbors())])
knnCv = GridSearchCV(pipe, param_grid={"knn__n_neighbors":[3,5,7,9,11]},cv=5,scoring="recall")
knnCv.fit(X_train, y_train)
y_pred = knnCv.predict(X_test)
print(f"accuracy score:{accuracy_score(y_test,y_pred)}")
print(f"precision score:{precision_score(y_test,y_pred,average="macro")}")
print(f"recall score:{recall_score(y_test,y_pred,average="macro")}")
res=pd.DataFrame(knnCv.cv_results_)
print(res)
print(knnCv.best_params_)
# Out:
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:953: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 942, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 308, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 399, in _score
#     response_method = _check_response_method(estimator, self._response_method)
#   File "c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2286, in _check_response_method
#     raise AttributeError(
#     ...<2 lines>...
#     )
# AttributeError: Pipeline has none of the following attributes: predict.
#
#   warnings.warn(
# c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:32, in _AvailableIfDescriptor._check(self, obj, owner)
#      31 try:
# ---> 32     check_result = self.check(obj)
#      33 except Exception as e:
#
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\pipeline.py:77, in _final_estimator_has.<locals>.check(self)
#      75 def check(self):
#      76     # raise original `AttributeError` if `attr` does not exist
# ---> 77     getattr(self._final_estimator, attr)
#      78     return True
#
# AttributeError: 'NearestNeighbors' object has no attribute 'predict'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:32, in _AvailableIfDescriptor._check(self, obj, owner)
#      31 try:
# ---> 32     check_result = self.check(obj)
#      33 except Exception as e:
#
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:374, in _search_estimator_has.<locals>.check(self)
#     372 if hasattr(self, "best_estimator_"):
#     373     # raise an AttributeError if `attr` does not exist
# --> 374     getattr(self.best_estimator_, attr)
#     375     return True
#
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:43, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      40 if obj is not None:
#      41     # delegate only on instances, not the classes.
#      42     # this is to allow access to the docstrings.
# ---> 43     self._check(obj, owner=owner)
#      44     out = MethodType(self.fn, obj)
#
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:34, in _AvailableIfDescriptor._check(self, obj, owner)
#      33 except Exception as e:
# ---> 34     raise AttributeError(attr_err_msg) from e
#      36 if not check_result:
#
# AttributeError: This 'Pipeline' has no attribute 'predict'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 knnCv = GridSearchCV(pipe, param_grid={"knn__n_neighbors":[3,5,7,9,11]},cv=5,scoring="recall")
#       3 knnCv.fit(X_train, y_train)
# ----> 4 y_pred = knnCv.predict(X_test)
#       5 print(f"accuracy score:{accuracy_score(y_test,y_pred)}")
#       6 print(f"precision score:{precision_score(y_test,y_pred,average="macro")}")
#
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:43, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      39 def __get__(self, obj, owner=None):
#      40     if obj is not None:
#      41         # delegate only on instances, not the classes.
#      42         # this is to allow access to the docstrings.
# ---> 43         self._check(obj, owner=owner)
#      44         out = MethodType(self.fn, obj)
#      46     else:
#      47         # This makes it possible to use the decorated method as an unbound method,
#      48         # for instance when monkeypatching.
#
# File c:\Users\AK-PC\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:34, in _AvailableIfDescriptor._check(self, obj, owner)
#      32     check_result = self.check(obj)
#      33 except Exception as e:
# ---> 34     raise AttributeError(attr_err_msg) from e
#      36 if not check_result:
#      37     raise AttributeError(attr_err_msg)
#
# AttributeError: This 'GridSearchCV' has no attribute 'predict'
